# %%
import matplotlib.pyplot as plt
import seaborn as sns
#figsize(13, 8)
sns.set(font_scale=1.4)
# %config InlineBackend.figure_format = 'retina'
plt.style.use(['seaborn-colorblind', 'seaborn-darkgrid'])

# %%
from environments.paddle.agent import Agent

# %% [markdown]
# ## Run simulation

# %%
agent = Agent()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_features (InputLayer)  [(None, 5)]               0
# _________________________________________________________________
# hidden_1 (Dense)             (None, 64)                384
# _________________________________________________________________
# hidden_2 (Dense)             (None, 32)                2080
# _________________________________________________________________
# output (Dense)               (None, 3)                 99
# ...
# Total params: 2,563
# Trainable params: 2,563
# Non-trainable params: 0
# _________________________________________________________________

# %%
agent.collect_validation_set()
# Out:
# Playing random policy game to collect validation set

# %%
agent.val_set.shape
# Out:
# (1000,)

# %%
agent.env.reset()
# Out:
# [0.0, 0.0, 1.0, -3, -3]

# %% [markdown]
# ### Train

# %%
agent.train(epochs=100)

# %% [markdown]
# ### Training plots

# %%
y = agent.total_reward_per_epoch
sns.lineplot(x=range(len(y)), y=y)
plt.title("Training metric - Reward collected per game")
plt.xlabel("epochs")
plt.ylabel("Total reward per game")
# Out:
# Text(0, 0.5, 'Total reward per game')

# %%
y = agent.val_score_per_epoch
sns.lineplot(x=range(len(y)), y=y)
plt.title("Training metric - Val score per game")
plt.xlabel("epochs")
plt.ylabel("Total reward per game")
# Out:
# Text(0, 0.5, 'Total reward per game')
