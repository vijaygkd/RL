# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from environments.paddle.agent import Agent

# %% [markdown]
# ## Run simulation

# %%
agent = Agent()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_features (InputLayer)  [(None, 5)]               0
# _________________________________________________________________
# hidden_1 (Dense)             (None, 64)                384
# _________________________________________________________________
# hidden_2 (Dense)             (None, 32)                2080
# _________________________________________________________________
# output (Dense)               (None, 3)                 99
# ...
# Total params: 2,563
# Trainable params: 2,563
# Non-trainable params: 0
# _________________________________________________________________

# %%
game_rewards = agent.train(epochs=10)

# %%
sns.lineplot(x=range(len(game_rewards)), y=game_rewards)
plt.title("Reward collected per game")
plt.xlabel("games")
plt.ylabel("total_reward_per_game")
# Out:
# Text(0, 0.5, 'total_reward_per_game')
